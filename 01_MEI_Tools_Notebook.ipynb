# %% [markdown]
# # MEI Tools: Metadata and Music Feature Processing
#
# This notebook guides you through two workflows for working with MEI (Music Encoding Initiative) files:
#
# 1. **Metadata workflow** — extract existing metadata into a CSV, edit that CSV to add or correct information, then apply the updated metadata back to a corpus of MEI files.
# 2. **Music feature workflow** — correct common encoding issues (editorial accidentals, incipits, empty verses, etc.).
#
# The tools support MEI files produced by four common applications: **MuseScore**, **Sibelius** (via the sibmei plug-in), **Humdrum/Verovio**, and **mei-friend**.  Files are detected automatically — you do not need to specify the source application.
#
# > **CRIM Project users:** see Section 4 for a dedicated workflow that uses the CRIM metadata spreadsheet format.
#
# ---
#
# ### Installation
#
# Install the package directly from GitHub:
#
# ```
# pip install git+https://github.com/RichardFreedman/mei_tools.git
# ```

# %% [markdown]
# ---
# ## 1. Import Libraries
#
# Run this cell before anything else.

# %%
from mei_tools import MEI_Metadata_Extractor
from mei_tools import MEI_Metadata_Updater_Generic
from mei_tools import MEI_Music_Feature_Processor
import glob
import os

# %% [markdown]
# ---
# ## 2. Extract Metadata from Your MEI Files
#
# The first step is to read your MEI files and pull out whatever metadata they already contain.  The result is a **CSV file** — one row per MEI file — that you can open in Excel, Google Sheets, or any spreadsheet application.
#
# Each source application (MuseScore, Sibelius, Humdrum, mei-friend) stores metadata in different locations inside the MEI header.  The extractor finds the right location automatically and collects everything into a single consistent table.
#
# > **Sibelius users:** Sibelius exports UTF-16 encoded files, which are not directly readable by most tools.  The extractor converts them to UTF-8 automatically — you do not need to do anything special.

# %% [markdown]
# ### 2a. Specify your folders
#
# - `mei_input_folder` — the folder containing the MEI files you want to extract metadata from, for example: `A_mei_to_process`.
# - `csv_output_folder` — the folder where the extracted CSV file(s) will be saved, for example: `B_extracted_metadata_csv`
#
# Use an absolute path (e.g. `/Users/yourname/Documents/my_corpus`) or a path relative to this notebook.

# %%
# Folder containing your MEI files
mei_input_folder = 'A_mei_to_process'

# Folder where extracted CSV files will be written
csv_output_folder = 'B_extracted_metadata_csv'

# %% [markdown]
# ### 2b. Run the extractor
#
# One CSV file is created for each source type found in your folder (e.g. `muse_score_extracted_metadata.csv`, `sib_extracted_metadata.csv`).  If all your files come from the same application there will be just one CSV.

# %%
extractor = MEI_Metadata_Extractor(verbose=True)
extractor.save_csvs(mei_input_folder, csv_output_folder)
# Out:
# Processing Bach_BWV_0772.mei …
# Processing Bach_BWV_0773.mei …
# Processing Bach_BWV_0774.mei …
# Processing Bach_BWV_0775.mei …
# Processing Bach_BWV_0776.mei …
# Processing Bach_BWV_0777.mei …
# Processing Bach_BWV_0778.mei …
# Processing Bach_BWV_0779.mei …
# Processing Bach_BWV_0780.mei …
# Processing Bach_BWV_0781.mei …
# Processing Bach_BWV_0782.mei …
# Processing Bach_BWV_0783.mei …
# Processing Bach_BWV_0784.mei …
# Processing Bach_BWV_0785.mei …
# Processing Bach_BWV_0786.mei …
# Saved 15 row(s) → B_extracted_metadata_csv/muse_score_extracted_metadata.csv

# %% [markdown]
# ### 2c. Understanding your extracted CSV
#
# Open the CSV in a spreadsheet application.  You will see one row per MEI file and the following columns:
#
# | Column | Contents |
# |--------|----------|
# | `filename` | The exact filename of the MEI file.  **Do not change this** — it is used to match rows back to files. |
# | `source_type` | Detected application: `musescore`, `sibelius`, `humdrum`, or `mei_friend`. |
# | `mei_version` | MEI schema version declared in the file. |
# | `title` | Main title of the work. |
# | `composer_name` | Composer's name as it appears in the file. |
# | `composer_auth` | Authority system used (e.g. VIAF, GND). |
# | `composer_auth_uri` | Full URI to the composer's authority record. |
# | `editors` | Names and roles of editors/encoders (see below). |
# | `encoding_date` | Date the file was encoded or last edited. |
# | `rights` | Rights or availability statement. |
# | `publisher` | Publisher name, if present. |
# | `distributor` | Distributor(s), if present. |
# | `genre` | Genre or classification term. |
# | `encoding_application` | Software used to create the file. |
# | `work_title` | Title as recorded in the workList section (may differ from the main title). |
# | `movement_name` | Movement name (Humdrum files). |
# | `source_title` | Title of the physical source edition (Humdrum files). |
# | `source_editor` | Editor of the source edition (Humdrum files). |
# | `source_encoder` | Person who encoded the file (Humdrum files). |
# | `edition_version` | Version identifier of the edition (Humdrum files). |
# | `encoding_annot` | Free-text note about the encoding (Humdrum files). |
# | `humdrum_id` | Internal Humdrum identifier (Humdrum files). |
#
# Columns that do not apply to a given source type are left blank.
#
# ---
#
# #### How to record multiple editors or distributors
#
# Use a **pipe character (`|`)** to separate multiple values in a single cell.  Each value will become its own element in the updated MEI file.
#
# **Editors** can optionally include a role in square brackets:
#
# ```
# Jane Smith [editor]|Robert Jones [encoder]|Maria Lopez [analyst]
# ```
#
# If you omit the role brackets, the name is written without a role attribute.
#
# **Distributors** (the `distributor` column) follow the same pattern:
#
# ```
# Haverford College|CESR Tours|The CRIM Project
# ```
#
# ---
#
# #### What happens if a cell is left empty?
#
# **Nothing** — the existing content of that field in the MEI file is left exactly as it is.  You only need to fill in cells where you want to make a change.  This means you can apply the same CSV to update just one or two fields across a large corpus without touching anything else.
#
# ---
#
# #### Saving your edited CSV
#
# Save your edited CSV in any convenient location.  In the next step you will point the updater either to:
# - a **local file path** (e.g. `C_updated_metadata_csv_files/my_corpus_metadata.csv`), or
# - a **URL** — Google Sheets and GitHub both work.
#
# **Google Sheets:** File → Share → Publish to web → select the sheet → choose *Comma-separated values (.csv)* → copy the URL.
#
# **GitHub:** navigate to the raw file view and copy the URL (it should start with `https://raw.githubusercontent.com/…`).

# %% [markdown]
# ---
# ## 3. Apply Updated Metadata to Your MEI Files
#
# Once you have edited your CSV, this step reads it and writes the new values into each MEI file.  Updated files are saved to a separate output folder with `_rev` added to their names (e.g. `MySong.mei` → `MySong_rev.mei`), so your originals are never overwritten.
#
# > **Note:** Only non-empty cells are applied.  If you left a cell blank, the existing MEI content for that field is preserved unchanged.

# %% [markdown]
# ### 3a. Specify folders and your updated CSV

# %%
# Folder containing the MEI files you want to update
#   (can be the same folder used in Step 2, or a different corpus)
mei_input_folder = 'A_mei_to_process'

# Your updated CSV — local path OR a URL (Google Sheets, GitHub raw)
csv_source = 'C_updated_metadata_csv_files/updated_metadata.csv'  # Example using a local file path

# Example using a Google Sheets URL:
# csv_source = 'https://docs.google.com/spreadsheets/d/e/YOURKEY/pub?output=csv'

# Example using a GitHub raw URL:
# csv_source = 'https://raw.githubusercontent.com/yourorg/yourrepo/main/metadata.csv'

# Folder where updated MEI files will be written
mei_output_folder = 'D_mei_with_updated_metadata'

# %%
csv_source
# Out:
# 'C_updated_metadata_csv_files/updated_metadata.csv'

# %% [markdown]
# ### 3b. Run the updater

# %%
updater = MEI_Metadata_Updater_Generic(verbose=True)
updater.process_folder(
    input_folder=mei_input_folder,
    csv_source=csv_source,
    output_folder=mei_output_folder
)
# Out:
# Loaded 7 row(s) from C_updated_metadata_csv_files/updated_metadata.csv
#   No CSV row for Bach_BWV_0772.mei — skipping
#   No CSV row for Bach_BWV_0773.mei — skipping
#   No CSV row for Bach_BWV_0774.mei — skipping
#   No CSV row for Bach_BWV_0775.mei — skipping
#   No CSV row for Bach_BWV_0776.mei — skipping
#   No CSV row for Bach_BWV_0777.mei — skipping
#   No CSV row for Bach_BWV_0778.mei — skipping
#   No CSV row for Bach_BWV_0779.mei — skipping
#   No CSV row for Bach_BWV_0780.mei — skipping
#   No CSV row for Bach_BWV_0781.mei — skipping
#   No CSV row for Bach_BWV_0782.mei — skipping
#   No CSV row for Bach_BWV_0783.mei — skipping
#   No CSV row for Bach_BWV_0784.mei — skipping
#   No CSV row for Bach_BWV_0785.mei — skipping
#   No CSV row for Bach_BWV_0786.mei — skipping
# Done. Updated 0 file(s), skipped 15.

# %% [markdown]
# #### What to expect
#
# - A line is printed for each file that is updated.
# - Files whose name does not appear in the CSV are skipped with a note.
# - A summary at the end shows how many files were updated and how many were skipped.
# - If a file cannot be parsed (e.g. corrupted XML), an error message is printed and processing continues with the next file.

# %% [markdown]
# ---
# ## 4. CRIM Project Workflow
#
# If you are working with the **Citations: The Renaissance Imitation Mass (CRIM) Project**, use this section instead of Sections 2–3.  The CRIM workflow uses a different set of column names that match the existing CRIM metadata spreadsheet, and it writes additional source-provenance fields (publisher, shelfmark, repository, etc.) into a `manifestationList` section of each MEI file.
#
# The CRIM metadata columns are:
#
# | Column | Contents |
# |--------|----------|
# | `MEI_Name` | Exact filename — **do not change** |
# | `Title` | Work title |
# | `Composer_Name` | Composer name |
# | `Composer_VIAF` | Full VIAF URI for the composer |
# | `Editor` | Pipe-separated editor names |
# | `Copyright_Owner` | Pipe-separated copyright holders |
# | `Rights_Statement` | Rights or license text |
# | `Genre` | Genre |
# | `Source_Title` | Title of the printed source edition |
# | `Source_Publisher_1` | First publisher of the source |
# | `Publisher_1_VIAF` | VIAF URI for first publisher |
# | `Source_Date` | Publication date of the source |
# | `Source_Institution` | Library or archive holding the source |
# | `Source_Shelfmark` | Shelfmark / call number |
# | `Source_Location` | City or location of the institution |
# | `Source_Publisher_2` | Second publisher, if any |
# | `Publisher_2_VIAF` | VIAF URI for second publisher |
#
# Fields that are already present in your MEI files (from a previous CRIM processing run) will be extracted automatically.  Fields not yet in the files will be blank for you to fill in.

# %% [markdown]
# ### 4a. Extract metadata in CRIM mode
#
# All MEI files in the folder are written to a single CSV called `crim_extracted_metadata.csv`.

# %%
# Folder containing CRIM MEI files
mei_input_folder = 'A_mei_to_process'

# Folder where the CSV will be saved
csv_output_folder = 'B_extracted_metadata_csv'

crim_extractor = MEI_Metadata_Extractor(verbose=True, crim_mode=True)
crim_extractor.save_csvs(mei_input_folder, csv_output_folder)
# Out:
# Processing Ror0101.mei …
# Processing Ror0102.mei …
# Processing Ror0103.mei …
# Processing Ror0104.mei …
# Processing Ror0105.mei …
# Processing Ror0106.mei …
# Processing Ror0107.mei …
# Saved 7 row(s) → sample_extracted_metadata_csv_files/crim_extracted_metadata.csv

# %% [markdown]
# ### 4b. Edit your CRIM metadata CSV
#
# Open `crim_extracted_metadata.csv`, fill in or correct the columns, and save it — locally or to a shared spreadsheet.
#
# The same rules apply as in Section 2c:
# - Leave a cell blank to preserve the existing MEI value.
# - Separate multiple editors with `|`: `André Vierendeels|Richard Freedman`.
# - Separate multiple copyright owners with `|`: `Haverford College|CESR Tours`.

# %% [markdown]
# ### 4c. Apply updated CRIM metadata

# %%
# Folder containing your CRIM MEI files
mei_input_folder = 'A_mei_to_process'

# Your updated CRIM CSV — local path or URL. for example:
# csv_source = 'C_updated_metadata_csv_files/updated_crim_metadata.csv'  # Example using a local file path

# Example: load directly from the shared CRIM Google Sheet
csv_source = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSYa2WllTX_oOwDBI_is9hnqUGBzoksEj0YgvW_ns_nL04BuC7GdDN1IYoZLsIvjwjtkF8C6bVeSmXo/pub?output=csv'

# Output folder for updated files
mei_output_folder = 'D_mei_with_updated_metadata'

crim_updater = MEI_Metadata_Updater_Generic(verbose=True)
crim_updater.process_folder(
    input_folder=mei_input_folder,
    csv_source=csv_source,
    output_folder=mei_output_folder,
    crim_mode=True
)
# Out:
# Loaded 317 row(s) from https://docs.google.com/spreadsheets/d/e/2PACX-1vSYa2WllTX_oOwDBI_is9hnqUGBzoksEj0YgvW_ns_nL04BuC7GdDN1IYoZLsIvjwjtkF8C6bVeSmXo/pub?output=csv
#   No CSV row for Ror0101.mei — skipping
#   No CSV row for Ror0102.mei — skipping
#   No CSV row for Ror0103.mei — skipping
#   No CSV row for Ror0104.mei — skipping
#   No CSV row for Ror0105.mei — skipping
#   No CSV row for Ror0106.mei — skipping
#   No CSV row for Ror0107.mei — skipping
# Done. Updated 0 file(s), skipped 7.

# %% [markdown]
# ---
# ## 5. Correcting Music Features
#
# The `MEI_Music_Feature_Processor` corrects common encoding issues that arise when exporting MEI from notation software.  Each correction can be switched on or off independently.
#
# Available options, with their default values:
#
# | Option | Default | What it does |
# |--------|---------|--------------|
# | `resolve_multibar_ties` | `True` | Converts standalone `<tie>` elements spanning multiple measures into note-level `@tie` attributes (`i` / `m` / `t`) |
# | `remove_incipit` | `True` | Removes the incipit measure (labeled 0 / n=1) and renumbers the remaining measures from 1 |
# | `remove_incipit_leuven` | `False` | Removes Leuven-style incipits (leading invisible-barline measures); transfers meter from the following scoreDef to the first scoreDef |
# | `remove_pb` | `True` | Removes all `<pb>` page-break elements |
# | `remove_sb` | `True` | Removes all `<sb>` system-break elements |
# | `remove_annotation` | `True` | Removes all `<annot>` annotation elements |
# | `remove_ligature_bracket` | `True` | Removes `<bracketSpan>` ligature-bracket elements |
# | `remove_dir` | `True` | Removes all `<dir>` direction / text-direction elements |
# | `remove_variants` | `True` | Collapses `<app>` variant apparatus: retains the `<lem>` reading and discards all `<rdg>` alternatives |
# | `remove_anchored_text` | `True` | Removes `<anchoredText>` elements |
# | `remove_timestamp` | `True` | Strips `tstamp.real`, `vel`, `tstamp`, and `tstamp2` attributes from notes, rests, whole-measure rests, and ties |
# | `remove_chord` | `True` | Removes `<chord>` wrapper elements |
# | `check_for_chords` | `True` | Reports any remaining `<chord>` elements and the measure numbers where they appear (diagnostic only — does not remove) |
# | `fix_elisions` | `True` | Corrects multi-syllable `<verse>` elements: concatenates elided syllables with `=` and sets proper `con` / `wordpos` attributes |
# | `fix_musescore_elisions` | `True` | Fixes MuseScore-specific elision encoding: converts `con="b"` to `con="d"` and replaces combining breve characters with underscores |
# | `slur_to_tie` | `True` | Re-tags `<slur>` elements as `<tie>` (also removes the `layer`, `tstamp`, `tstamp2`, and `staff` attributes that are invalid on ties) |
# | `correct_ficta` | `True` | Converts colored (red) notes to editorial accidentals: wraps the accidental in `<supplied reason="edit">` and promotes `accid.ges` to `accid` |
# | `voice_labels` | `True` | Moves `<label>` child-element text into the `@label` attribute of the enclosing `<staffDef>` |
# | `correct_mrests` | `True` | Splits `<mRest>` whole-measure rests inside 3/1 measures into three individual whole rests |
# | `collapse_layers` | `False` | Merges all voice layers into layer 1 |
# | `remove_senfl_bracket` | `False` | Removes `<line type="bracket">` Senfl-edition bracket elements |
# | `remove_empty_verse` | `False` | Removes `<verse>` elements that contain no children |
# | `remove_lyrics` | `False` | Removes all `<verse>` elements (strips all lyrics from the file) |
# | `correct_cmme_time_signatures` | `False` | Moves meter attributes from `<staffDef>` up to the enclosing `<scoreDef>` (fixes CMME export format) |
# | `correct_jrp_time_signatures` | `False` | Promotes meter from `<meterSig>` child elements to `@meter.count` / `@meter.unit` attributes on `<scoreDef>` (fixes JRP export format) |
# | `report_scoredef_mismatches` | `False` | Scans each measure and reports where the `dur.ppq` total of staff n=1 does not match the current `scoreDef` meter; does not modify the file |
# | `fix_scoredef_meters` | `False` | Inserts a corrective `<scoreDef>` before each mismatching measure, inferred from the actual `dur.ppq` total; saves the result to the output folder |
# | `simplify_choice` | `False` | Replaces each `<choice>` element with the `<note>` or `<rest>` from its `<corr>` child, removing the `color` attribute from the kept element |

# %% [markdown]
# ### 5a. Create an instance of the processor

# %%
music_feature_processor = MEI_Music_Feature_Processor()

# %% [markdown]
# ### 5b. Specify input and output folders

# %%
# Input: folder of MEI files to process
# note that this can be the same folder used in previous steps, or a different corpus, for example:
mei_paths = glob.glob('D_mei_with_updated_metadata/*.mei')

# Output folder, for example
output_folder = 'E_mei_with_updated_music_features'

# %%
mei_paths
# Out:
# ['D_mei_with_updated_metadata/DC0319.mei',
#  'D_mei_with_updated_metadata/DC1007.mei',
#  'D_mei_with_updated_metadata/DC1013.mei',
#  'D_mei_with_updated_metadata/DC0523.mei',
#  'D_mei_with_updated_metadata/DC0709.mei',
#  'D_mei_with_updated_metadata/DC0721.mei',
#  'D_mei_with_updated_metadata/DC0912.mei',
#  'D_mei_with_updated_metadata/DC0906.mei',
#  'D_mei_with_updated_metadata/DC0907.mei',
#  'D_mei_with_updated_metadata/DC0913.mei',
#  'D_mei_with_updated_metadata/DC0720.mei',
#  'D_mei_with_updated_metadata/DC0708.mei',
#  'D_mei_with_updated_metadata/DC0522.mei',
#  'D_mei_with_updated_metadata/DC1012.mei',
#  'D_mei_with_updated_metadata/DC1006.mei',
#  'D_mei_with_updated_metadata/DC0318.mei',
#  'D_mei_with_updated_metadata/DC0118.mei',
#  'D_mei_with_updated_metadata/DC0124.mei',
#  'D_mei_with_updated_metadata/DC1010.mei',
#  'D_mei_with_updated_metadata/DC1004.mei',
#  'D_mei_with_updated_metadata/DC0508.mei',
#  'D_mei_with_updated_metadata/DC0520.mei',
#  'D_mei_with_updated_metadata/DC0722.mei',
#  'D_mei_with_updated_metadata/DC0905.mei',
#  'D_mei_with_updated_metadata/DC0911.mei',
#  'D_mei_with_updated_metadata/DC0910.mei',
#  'D_mei_with_updated_metadata/DC0904.mei',
#  'D_mei_with_updated_metadata/DC0723.mei',
#  'D_mei_with_updated_metadata/DC0521.mei',
#  'D_mei_with_updated_metadata/DC0509.mei',
#  'D_mei_with_updated_metadata/DC1005.mei',
#  'D_mei_with_updated_metadata/DC1011.mei',
#  'D_mei_with_updated_metadata/DC0125.mei',
#  'D_mei_with_updated_metadata/DC0119.mei',
#  'D_mei_with_updated_metadata/DC0121.mei',
#  'D_mei_with_updated_metadata/DC0109.mei',
#  'D_mei_with_updated_metadata/DC1015.mei',
#  'D_mei_with_updated_metadata/DC1001.mei',
#  'D_mei_with_updated_metadata/DC0525.mei',
#  'D_mei_with_updated_metadata/DC0519.mei',
#  'D_mei_with_updated_metadata/DC0727.mei',
#  'D_mei_with_updated_metadata/DC0914.mei',
#  'D_mei_with_updated_metadata/DC0915.mei',
#  'D_mei_with_updated_metadata/DC0901.mei',
#  'D_mei_with_updated_metadata/DC0726.mei',
#  'D_mei_with_updated_metadata/DC0518.mei',
#  'D_mei_with_updated_metadata/DC0524.mei',
#  'D_mei_with_updated_metadata/DC1014.mei',
#  'D_mei_with_updated_metadata/DC0322.mei',
#  'D_mei_with_updated_metadata/DC0108.mei',
#  'D_mei_with_updated_metadata/DC0120.mei',
#  'D_mei_with_updated_metadata/DC0122.mei',
#  'D_mei_with_updated_metadata/DC0320.mei',
#  'D_mei_with_updated_metadata/DC1002.mei',
#  'D_mei_with_updated_metadata/DC0308.mei',
#  'D_mei_with_updated_metadata/DC1016.mei',
#  'D_mei_with_updated_metadata/DC0724.mei',
#  'D_mei_with_updated_metadata/DC0718.mei',
#  'D_mei_with_updated_metadata/DC0917.mei',
#  'D_mei_with_updated_metadata/DC0903.mei',
#  'D_mei_with_updated_metadata/DC0902.mei',
#  'D_mei_with_updated_metadata/DC0916.mei',
#  'D_mei_with_updated_metadata/DC0719.mei',
#  'D_mei_with_updated_metadata/DC0725.mei',
#  'D_mei_with_updated_metadata/DC1017.mei',
#  'D_mei_with_updated_metadata/DC0309.mei',
#  'D_mei_with_updated_metadata/DC1003.mei',
#  'D_mei_with_updated_metadata/DC0321.mei',
#  'D_mei_with_updated_metadata/DC0123.mei',
#  'D_mei_with_updated_metadata/DC0622.mei',
#  'D_mei_with_updated_metadata/DC0805.mei',
#  'D_mei_with_updated_metadata/DC0811.mei',
#  'D_mei_with_updated_metadata/DC0408.mei',
#  'D_mei_with_updated_metadata/DC0420.mei',
#  'D_mei_with_updated_metadata/DC1110.mei',
#  'D_mei_with_updated_metadata/DC1104.mei',
#  'D_mei_with_updated_metadata/DC0226.mei',
#  'D_mei_with_updated_metadata/DC1105.mei',
#  'D_mei_with_updated_metadata/DC1111.mei',
#  'D_mei_with_updated_metadata/DC0421.mei',
#  'D_mei_with_updated_metadata/DC0409.mei',
#  'D_mei_with_updated_metadata/DC0810.mei',
#  'D_mei_with_updated_metadata/DC0804.mei',
#  'D_mei_with_updated_metadata/DC0623.mei',
#  'D_mei_with_updated_metadata/DC0609.mei',
#  'D_mei_with_updated_metadata/DC0621.mei',
#  'D_mei_with_updated_metadata/DC0812.mei',
#  'D_mei_with_updated_metadata/DC0806.mei',
#  'D_mei_with_updated_metadata/DC0423.mei',
#  'D_mei_with_updated_metadata/DC1107.mei',
#  'D_mei_with_updated_metadata/DC0219.mei',
#  'D_mei_with_updated_metadata/DC1113.mei',
#  'D_mei_with_updated_metadata/DC0225.mei',
#  'D_mei_with_updated_metadata/DC0224.mei',
#  'D_mei_with_updated_metadata/DC1112.mei',
#  'D_mei_with_updated_metadata/DC0218.mei',
#  'D_mei_with_updated_metadata/DC1106.mei',
#  'D_mei_with_updated_metadata/DC0422.mei',
#  'D_mei_with_updated_metadata/DC0807.mei',
#  'D_mei_with_updated_metadata/DC0813.mei',
#  'D_mei_with_updated_metadata/DC0620.mei',
#  'D_mei_with_updated_metadata/DC0608.mei',
#  'D_mei_with_updated_metadata/DC0624.mei',
#  'D_mei_with_updated_metadata/DC0618.mei',
#  'D_mei_with_updated_metadata/DC0817.mei',
#  'D_mei_with_updated_metadata/DC0803.mei',
#  'D_mei_with_updated_metadata/DC0220.mei',
#  'D_mei_with_updated_metadata/DC1102.mei',
#  'D_mei_with_updated_metadata/DC1116.mei',
#  'D_mei_with_updated_metadata/DC0208.mei',
#  'D_mei_with_updated_metadata/DC0209.mei',
#  'D_mei_with_updated_metadata/DC1117.mei',
#  'D_mei_with_updated_metadata/DC1103.mei',
#  'D_mei_with_updated_metadata/DC0221.mei',
#  'D_mei_with_updated_metadata/DC0802.mei',
#  'D_mei_with_updated_metadata/DC0816.mei',
#  'D_mei_with_updated_metadata/DC0619.mei',
#  'D_mei_with_updated_metadata/DC0625.mei',
#  'D_mei_with_updated_metadata/DC0814.mei',
#  'D_mei_with_updated_metadata/DC0419.mei',
#  'D_mei_with_updated_metadata/DC0223.mei',
#  'D_mei_with_updated_metadata/DC1115.mei',
#  'D_mei_with_updated_metadata/DC1101.mei',
#  'D_mei_with_updated_metadata/DC1114.mei',
#  'D_mei_with_updated_metadata/DC0222.mei',
#  'D_mei_with_updated_metadata/DC0418.mei',
#  'D_mei_with_updated_metadata/DC0424.mei',
#  'D_mei_with_updated_metadata/DC0815.mei',
#  'D_mei_with_updated_metadata/DC0801.mei',
#  'D_mei_with_updated_metadata/DC0603.mei',
#  'D_mei_with_updated_metadata/DC0617.mei',
#  'D_mei_with_updated_metadata/DC0824.mei',
#  'D_mei_with_updated_metadata/DC0818.mei',
#  'D_mei_with_updated_metadata/DC0401.mei',
#  'D_mei_with_updated_metadata/DC0415.mei',
#  'D_mei_with_updated_metadata/DC0213.mei',
#  'D_mei_with_updated_metadata/DC1119.mei',
#  'D_mei_with_updated_metadata/DC0207.mei',
#  'D_mei_with_updated_metadata/DC0206.mei',
#  'D_mei_with_updated_metadata/DC1118.mei',
#  'D_mei_with_updated_metadata/DC0212.mei',
#  'D_mei_with_updated_metadata/DC0414.mei',
#  'D_mei_with_updated_metadata/DC0819.mei',
#  'D_mei_with_updated_metadata/DC0825.mei',
#  'D_mei_with_updated_metadata/DC0616.mei',
#  'D_mei_with_updated_metadata/DC0602.mei',
#  'D_mei_with_updated_metadata/DC0614.mei',
#  'D_mei_with_updated_metadata/DC0416.mei',
#  'D_mei_with_updated_metadata/DC0402.mei',
#  'D_mei_with_updated_metadata/DC0204.mei',
#  'D_mei_with_updated_metadata/DC0210.mei',
#  'D_mei_with_updated_metadata/DC0211.mei',
#  'D_mei_with_updated_metadata/DC0205.mei',
#  'D_mei_with_updated_metadata/DC0403.mei',
#  'D_mei_with_updated_metadata/DC0417.mei',
#  'D_mei_with_updated_metadata/DC0601.mei',
#  'D_mei_with_updated_metadata/DC0615.mei',
#  'D_mei_with_updated_metadata/DC0611.mei',
#  'D_mei_with_updated_metadata/DC0605.mei',
#  'D_mei_with_updated_metadata/DC0822.mei',
#  'D_mei_with_updated_metadata/DC0413.mei',
#  'D_mei_with_updated_metadata/DC0407.mei',
#  'D_mei_with_updated_metadata/DC0201.mei',
#  'D_mei_with_updated_metadata/DC0215.mei',
#  'D_mei_with_updated_metadata/DC1122.mei',
#  'D_mei_with_updated_metadata/DC0214.mei',
#  'D_mei_with_updated_metadata/DC0406.mei',
#  'D_mei_with_updated_metadata/DC0412.mei',
#  'D_mei_with_updated_metadata/DC0823.mei',
#  'D_mei_with_updated_metadata/DC0604.mei',
#  'D_mei_with_updated_metadata/DC0610.mei',
#  'D_mei_with_updated_metadata/DC0606.mei',
#  'D_mei_with_updated_metadata/DC0612.mei',
#  'D_mei_with_updated_metadata/DC0809.mei',
#  'D_mei_with_updated_metadata/DC0821.mei',
#  'D_mei_with_updated_metadata/DC0404.mei',
#  'D_mei_with_updated_metadata/DC0410.mei',
#  'D_mei_with_updated_metadata/DC1108.mei',
#  'D_mei_with_updated_metadata/DC0216.mei',
#  'D_mei_with_updated_metadata/DC0202.mei',
#  'D_mei_with_updated_metadata/DC1120.mei',
#  'D_mei_with_updated_metadata/DC1121.mei',
#  'D_mei_with_updated_metadata/DC0203.mei',
#  'D_mei_with_updated_metadata/DC0217.mei',
#  'D_mei_with_updated_metadata/DC1109.mei',
#  'D_mei_with_updated_metadata/DC0411.mei',
#  'D_mei_with_updated_metadata/DC0405.mei',
#  'D_mei_with_updated_metadata/DC0820.mei',
#  'D_mei_with_updated_metadata/DC0808.mei',
#  'D_mei_with_updated_metadata/DC0613.mei',
#  'D_mei_with_updated_metadata/DC0607.mei',
#  'D_mei_with_updated_metadata/DC0106.mei',
#  'D_mei_with_updated_metadata/DC0112.mei',
#  'D_mei_with_updated_metadata/DC1026.mei',
#  'D_mei_with_updated_metadata/DC0304.mei',
#  'D_mei_with_updated_metadata/DC0310.mei',
#  'D_mei_with_updated_metadata/DC0516.mei',
#  'D_mei_with_updated_metadata/DC0502.mei',
#  'D_mei_with_updated_metadata/DC0714.mei',
#  'D_mei_with_updated_metadata/DC0927.mei',
#  'D_mei_with_updated_metadata/DC0926.mei',
#  'D_mei_with_updated_metadata/DC0701.mei',
#  'D_mei_with_updated_metadata/DC0715.mei',
#  'D_mei_with_updated_metadata/DC0503.mei',
#  'D_mei_with_updated_metadata/DC0517.mei',
#  'D_mei_with_updated_metadata/DC0311.mei',
#  'D_mei_with_updated_metadata/DC0305.mei',
#  'D_mei_with_updated_metadata/DC0107.mei',
#  'D_mei_with_updated_metadata/DC0111.mei',
#  'D_mei_with_updated_metadata/DC0105.mei',
#  'D_mei_with_updated_metadata/DC1025.mei',
#  'D_mei_with_updated_metadata/DC0313.mei',
#  'D_mei_with_updated_metadata/DC0307.mei',
#  'D_mei_with_updated_metadata/DC1019.mei',
#  'D_mei_with_updated_metadata/DC0501.mei',
#  'D_mei_with_updated_metadata/DC0515.mei',
#  'D_mei_with_updated_metadata/DC0703.mei',
#  'D_mei_with_updated_metadata/DC0717.mei',
#  'D_mei_with_updated_metadata/DC0924.mei',
#  'D_mei_with_updated_metadata/DC0918.mei',
#  'D_mei_with_updated_metadata/DC0919.mei',
#  'D_mei_with_updated_metadata/DC0925.mei',
#  'D_mei_with_updated_metadata/DC0716.mei',
#  'D_mei_with_updated_metadata/DC0702.mei',
#  'D_mei_with_updated_metadata/DC0514.mei',
#  'D_mei_with_updated_metadata/DC1018.mei',
#  'D_mei_with_updated_metadata/DC0306.mei',
#  'D_mei_with_updated_metadata/DC0312.mei',
#  'D_mei_with_updated_metadata/DC1024.mei',
#  'D_mei_with_updated_metadata/DC0104.mei',
#  'D_mei_with_updated_metadata/DC0110.mei',
#  'D_mei_with_updated_metadata/DC0114.mei',
#  'D_mei_with_updated_metadata/DC0316.mei',
#  'D_mei_with_updated_metadata/DC1008.mei',
#  'D_mei_with_updated_metadata/DC0302.mei',
#  'D_mei_with_updated_metadata/DC1020.mei',
#  'D_mei_with_updated_metadata/DC0504.mei',
#  'D_mei_with_updated_metadata/DC0510.mei',
#  'D_mei_with_updated_metadata/DC0706.mei',
#  'D_mei_with_updated_metadata/DC0712.mei',
#  'D_mei_with_updated_metadata/DC0909.mei',
#  'D_mei_with_updated_metadata/DC0921.mei',
#  'D_mei_with_updated_metadata/DC0920.mei',
#  'D_mei_with_updated_metadata/DC0908.mei',
#  'D_mei_with_updated_metadata/DC0713.mei',
#  'D_mei_with_updated_metadata/DC0707.mei',
#  'D_mei_with_updated_metadata/DC0511.mei',
#  'D_mei_with_updated_metadata/DC0505.mei',
#  'D_mei_with_updated_metadata/DC1021.mei',
#  'D_mei_with_updated_metadata/DC0303.mei',
#  'D_mei_with_updated_metadata/DC1009.mei',
#  'D_mei_with_updated_metadata/DC0317.mei',
#  'D_mei_with_updated_metadata/DC0101.mei',
#  'D_mei_with_updated_metadata/DC0115.mei',
#  'D_mei_with_updated_metadata/DC0103.mei',
#  'D_mei_with_updated_metadata/DC0117.mei',
#  'D_mei_with_updated_metadata/DC0301.mei',
#  'D_mei_with_updated_metadata/DC0315.mei',
#  'D_mei_with_updated_metadata/DC1023.mei',
#  'D_mei_with_updated_metadata/DC0513.mei',
#  'D_mei_with_updated_metadata/DC0507.mei',
#  'D_mei_with_updated_metadata/DC0711.mei',
#  'D_mei_with_updated_metadata/DC0705.mei',
#  'D_mei_with_updated_metadata/DC0922.mei',
#  'D_mei_with_updated_metadata/DC0923.mei',
#  'D_mei_with_updated_metadata/DC0704.mei',
#  'D_mei_with_updated_metadata/DC0710.mei',
#  'D_mei_with_updated_metadata/DC0506.mei',
#  'D_mei_with_updated_metadata/DC0512.mei',
#  'D_mei_with_updated_metadata/DC1022.mei',
#  'D_mei_with_updated_metadata/DC0314.mei',
#  'D_mei_with_updated_metadata/DC0116.mei',
#  'D_mei_with_updated_metadata/DC0102.mei']

# %% [markdown]
# ### 5c. Process the files
#
# Edit the `True` / `False` values below to control which corrections are applied.

# %%
for mei_path in mei_paths:
    music_feature_processor.process_music_features(
        mei_path,
        output_folder=output_folder,
        # --- on by default ---
        resolve_multibar_ties=False,
        remove_incipit=False,
        remove_pb=False,
        remove_sb=False,
        remove_annotation=False,
        remove_ligature_bracket=False,
        remove_dir=False,
        remove_variants=True,
        remove_anchored_text=False,
        remove_timestamp=False,
        remove_chord=False,
        check_for_chords=True,
        fix_elisions=True,
        fix_musescore_elisions=False,
        slur_to_tie=False,
        correct_ficta=False,
        voice_labels=False,
        correct_mrests=True,
        # --- off by default ---
        remove_incipit_leuven=False,
        collapse_layers=False,
        remove_senfl_bracket=False,
        remove_empty_verse=False,
        remove_lyrics=False,
        correct_cmme_time_signatures=False,
        correct_jrp_time_signatures=False,
        fix_scoredef_meters=True,
        simplify_choice=True
    )
# Out:
# Getting DC0319
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 15
# Inserted scoreDef meter.count=3 meter.unit=1 before measure 16
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 18
#   Skipping fix for measure 27: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 45
# Found 5 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0319_rev.mei
# Getting DC1007
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 33
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 34
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC1007_rev.mei
# Getting DC1013
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 35
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 36
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC1013_rev.mei
# Getting DC0523
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 36
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0523_rev.mei
# Getting DC0709
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 21
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0709_rev.mei
# Getting DC0721
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 9
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 10
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 17
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 18
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 19
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 20
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 28
# Found 7 meter mismatches.
# Inserted 7 corrective scoreDef elements.
# Saved updated DC0721_rev.mei
# Getting DC0912
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 42
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0912_rev.mei
# Getting DC0906
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 15 3/1 measures check for mRests.
# Corrected 1 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 1
# Inserted scoreDef meter.count=3 meter.unit=1 before measure 11
#   Skipping fix for measure 29: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 42
# Found 4 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0906_rev.mei
# Getting DC0907
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 41
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0907_rev.mei
# Getting DC0913
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 25: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 35
# Found 2 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0913_rev.mei
# Getting DC0720
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 40
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0720_rev.mei
# Getting DC0708
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 36
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0708_rev.mei
# Getting DC0522
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 4 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 39
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0522_rev.mei
# Getting DC1012
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 10
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 11
#   Skipping fix for measure 39: no meter found for 5120 ppq
# Found 3 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC1012_rev.mei
# Getting DC1006
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 3 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 29
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 31
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 33
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC1006_rev.mei
# Getting DC0318
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 3 choice elements to simplify.
# Replaced 3 choice elements.
#   Skipping fix for measure 7: no meter found for 1792 ppq
#   Skipping fix for measure 22: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 24
# Found 3 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0318_rev.mei
# Getting DC0118
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 30 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 1
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 12
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 14
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 43
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0118_rev.mei
# Getting DC0124
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 6 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 1 choice elements to simplify.
# Replaced 1 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 6
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 7
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 34
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 35
#   Skipping fix for measure 44: no meter found for 5120 ppq
# Found 5 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0124_rev.mei
# Getting DC1010
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 4: no meter found for 1792 ppq
#   Skipping fix for measure 15: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 46
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 48
#   Skipping fix for measure 49: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 58
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 59
# Found 7 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC1010_rev.mei
# Getting DC1004
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 7 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 36
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 37
# Inserted scoreDef meter.count=3 meter.unit=1 before measure 38
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 40
#   Skipping fix for measure 43: no meter found for 1792 ppq
# Inserted scoreDef meter.count=3 meter.unit=1 before measure 45
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 47
#   Skipping fix for measure 50: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 52
# Found 9 meter mismatches.
# Inserted 7 corrective scoreDef elements.
# Saved updated DC1004_rev.mei
# Getting DC0508
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 5 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 65
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0508_rev.mei
# Getting DC0520
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 58
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0520_rev.mei
# Getting DC0722
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 29
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0722_rev.mei
# Getting DC0905
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 26: no meter found for 5120 ppq
# Found 1 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC0905_rev.mei
# Getting DC0911
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 52: no meter found for 4864 ppq
# Found 1 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC0911_rev.mei
# Getting DC0910
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 7 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 7
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 8
#   Skipping fix for measure 13: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 30
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 31
# Found 5 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0910_rev.mei
# Getting DC0904
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 3 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 21
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 28
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 30
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0904_rev.mei
# Getting DC0723
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 5
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 8
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 36
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0723_rev.mei
# Getting DC0521
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 5 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 17: no meter found for 1792 ppq
#   Skipping fix for measure 28: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 44
# Found 3 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0521_rev.mei
# Getting DC0509
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 33
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0509_rev.mei
# Getting DC1005
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 8
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 9
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 23
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC1005_rev.mei
# Getting DC1011
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 7: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 28
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 30
#   Skipping fix for measure 36: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 47
# Found 5 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC1011_rev.mei
# Getting DC0125
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 12 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 74
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0125_rev.mei
# Getting DC0119
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 32
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 34
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 45
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 46
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0119_rev.mei
# Getting DC0121
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 11
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 12
#   Skipping fix for measure 40: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 43
# Found 4 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0121_rev.mei
# Getting DC0109
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 26: no meter found for 1792 ppq
#   Skipping fix for measure 37: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 46
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 47
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 57
# Found 5 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0109_rev.mei
# Getting DC1015
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 11
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 12
#   Skipping fix for measure 31: no meter found for 1792 ppq
#   Skipping fix for measure 35: no meter found for 5120 ppq
# Found 4 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC1015_rev.mei
# Getting DC1001
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 50: no meter found for 5120 ppq
# Found 1 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC1001_rev.mei
# Getting DC0525
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 37
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0525_rev.mei
# Getting DC0519
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 6 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 14
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 15
#   Skipping fix for measure 25: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 39
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 40
# Found 5 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0519_rev.mei
# Getting DC0727
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 4 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 12
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 27
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0727_rev.mei
# Getting DC0914
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 36
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 37
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0914_rev.mei
# Getting DC0915
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 31: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 36
# Found 2 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0915_rev.mei
# Getting DC0901
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 29: no meter found for 1792 ppq
#   Skipping fix for measure 49: no meter found for 5120 ppq
# Found 2 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC0901_rev.mei
# Getting DC0726
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 2: no meter found for 1792 ppq
#   Skipping fix for measure 21: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 32
# Found 3 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0726_rev.mei
# Getting DC0518
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 28
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 29
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0518_rev.mei
# Getting DC0524
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 40
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0524_rev.mei
# Getting DC1014
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 28
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC1014_rev.mei
# Getting DC0322
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 24
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 26
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 30
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 31
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0322_rev.mei
# Getting DC0108
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 5: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 29
# Found 2 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0108_rev.mei
# Getting DC0120
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 31
#   Skipping fix for measure 34: no meter found for 5120 ppq
# Found 2 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0120_rev.mei
# Getting DC0122
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 1 choice elements to simplify.
# Replaced 1 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 59
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0122_rev.mei
# Getting DC0320
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 2 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 59
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0320_rev.mei
# Getting DC1002
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 16 3/1 measures check for mRests.
# Corrected 3 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 21: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 29
# Found 2 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC1002_rev.mei
# Getting DC0308
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 14
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 16
#   Skipping fix for measure 22: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 47
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 48
# Found 5 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0308_rev.mei
# Getting DC1016
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 10: no meter found for 1792 ppq
#   Skipping fix for measure 17: no meter found for 1536 ppq
#   Skipping fix for measure 19: no meter found for 1792 ppq
#   Skipping fix for measure 20: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 36
#   Skipping fix for measure 38: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 39
#   Skipping fix for measure 44: no meter found for 1792 ppq
#   Skipping fix for measure 49: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 52
# Found 10 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC1016_rev.mei
# Getting DC0724
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 24: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 37
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 38
# Found 3 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0724_rev.mei
# Getting DC0718
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 1 choice elements to simplify.
# Replaced 1 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 7
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 8
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 15
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 17
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 23
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 24
# Found 6 meter mismatches.
# Inserted 6 corrective scoreDef elements.
# Saved updated DC0718_rev.mei
# Getting DC0917
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 13
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 14
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 41
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0917_rev.mei
# Getting DC0903
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 32: no meter found for 5120 ppq
# Found 1 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC0903_rev.mei
# Getting DC0902
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 16
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 18
#   Skipping fix for measure 27: no meter found for 5120 ppq
# Found 3 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0902_rev.mei
# Getting DC0916
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 31
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0916_rev.mei
# Getting DC0719
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 23
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 25
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0719_rev.mei
# Getting DC0725
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 31
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 33
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 39
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0725_rev.mei
# Getting DC1017
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 1 choice elements to simplify.
# Replaced 1 choice elements.
#   Skipping fix for measure 5: no meter found for 1792 ppq
#   Skipping fix for measure 11: no meter found for 1792 ppq
#   Skipping fix for measure 41: no meter found for 1792 ppq
#   Skipping fix for measure 45: no meter found for 1792 ppq
#   Skipping fix for measure 47: no meter found for 5120 ppq
# Found 5 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC1017_rev.mei
# Getting DC0309
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 4: no meter found for 1792 ppq
#   Skipping fix for measure 9: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 15
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 17
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 20
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 21
# Found 6 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0309_rev.mei
# Getting DC1003
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 41: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 65
# Found 2 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC1003_rev.mei
# Getting DC0321
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=3 meter.unit=1 before measure 35
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 38
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 59
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0321_rev.mei
# Getting DC0123
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 35
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0123_rev.mei
# Getting DC0622
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 37
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0622_rev.mei
# Getting DC0805
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 2 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 37
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0805_rev.mei
# Getting DC0811
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 8
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 10
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 58
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0811_rev.mei
# Getting DC0408
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 5 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 11
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 12
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 20
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 39
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0408_rev.mei
# Getting DC0420
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 28
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0420_rev.mei
# Getting DC1110
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 27
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC1110_rev.mei
# Getting DC1104
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 38
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 40
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 44
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC1104_rev.mei
# Getting DC0226
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 15
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 16
#   Skipping fix for measure 26: no meter found for 1792 ppq
#   Skipping fix for measure 34: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 36
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 38
# Found 6 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0226_rev.mei
# Getting DC1105
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 6: no meter found for 1792 ppq
#   Skipping fix for measure 16: no meter found for 1792 ppq
#   Skipping fix for measure 26: no meter found for 1792 ppq
#   Skipping fix for measure 38: no meter found for 1792 ppq
#   Skipping fix for measure 49: no meter found for 1792 ppq
#   Skipping fix for measure 50: no meter found for 5120 ppq
# Found 6 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC1105_rev.mei
# Getting DC1111
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 9: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 29
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 31
#   Skipping fix for measure 38: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 40
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 42
# Found 6 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC1111_rev.mei
# Getting DC0421
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 44: no meter found for 5120 ppq
# Found 1 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC0421_rev.mei
# Getting DC0409
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 1 choice elements to simplify.
# Replaced 1 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 65
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0409_rev.mei
# Getting DC0810
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 3 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 26
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0810_rev.mei
# Getting DC0804
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 10 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 10
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 11
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 19
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 22
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 31
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 42
# Found 6 meter mismatches.
# Inserted 6 corrective scoreDef elements.
# Saved updated DC0804_rev.mei
# Getting DC0623
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 21
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 23
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 29
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 30
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0623_rev.mei
# Getting DC0609
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 8 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 2 choice elements to simplify.
# Replaced 2 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 1
# Inserted scoreDef meter.count=3 meter.unit=1 before measure 5
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 22
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0609_rev.mei
# Getting DC0621
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 51
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 52
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0621_rev.mei
# Getting DC0812
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 6 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 32
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0812_rev.mei
# Getting DC0806
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 28
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 30
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0806_rev.mei
# Getting DC0423
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 16 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 1
# Inserted scoreDef meter.count=3 meter.unit=1 before measure 9
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 19
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 21
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 28
# Found 5 meter mismatches.
# Inserted 5 corrective scoreDef elements.
# Saved updated DC0423_rev.mei
# Getting DC1107
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 41
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 43
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 57
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 58
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC1107_rev.mei
# Getting DC0219
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 15 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 1 choice elements to simplify.
# Replaced 1 choice elements.
# Inserted scoreDef meter.count=3 meter.unit=1 before measure 1
#   Skipping fix for measure 6: no meter found for 1792 ppq
#   Skipping fix for measure 28: no meter found for 1536 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 29
# Found 4 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0219_rev.mei
# Getting DC1113
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 11: no meter found for 1792 ppq
#   Skipping fix for measure 23: no meter found for 1792 ppq
#   Skipping fix for measure 40: no meter found for 5120 ppq
# Found 3 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC1113_rev.mei
# Getting DC0225
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 7
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 8
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 25
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 26
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 35
# Found 5 meter mismatches.
# Inserted 5 corrective scoreDef elements.
# Saved updated DC0225_rev.mei
# Getting DC0224
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 25
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0224_rev.mei
# Getting DC1112
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 9 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 2 choice elements to simplify.
# Replaced 2 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 12
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 13
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 23
#   Skipping fix for measure 39: no meter found for 5120 ppq
# Found 4 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC1112_rev.mei
# Getting DC0218
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 9 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 11
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 12
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 48
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 49
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0218_rev.mei
# Getting DC1106
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 2: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 36
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 39
# Found 3 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC1106_rev.mei
# Getting DC0422
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 40
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0422_rev.mei
# Getting DC0807
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 13: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 26
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 27
# Found 3 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0807_rev.mei
# Getting DC0813
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 31
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0813_rev.mei
# Getting DC0620
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 2 choice elements to simplify.
# Replaced 2 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 16
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 18
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 24
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 25
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0620_rev.mei
# Getting DC0608
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 5 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 48
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0608_rev.mei
# Getting DC0624
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 7: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 60
# Found 2 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0624_rev.mei
# Getting DC0618
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 1
#   Skipping fix for measure 9: no meter found for 1792 ppq
#   Skipping fix for measure 11: no meter found for 1792 ppq
#   Skipping fix for measure 15: no meter found for 1536 ppq
#   Skipping fix for measure 17: no meter found for 1536 ppq
#   Skipping fix for measure 18: no meter found for 1536 ppq
#   Skipping fix for measure 19: no meter found for 1536 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 42
# ...
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 35
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 37
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 42
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 46
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0706_rev.mei
# Getting DC0712
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 35
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 37
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0712_rev.mei
# Getting DC0909
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 1 choice elements to simplify.
# Replaced 1 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 39
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 41
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 44
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 45
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0909_rev.mei
# Getting DC0921
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 9: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 31
# Found 2 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0921_rev.mei
# Getting DC0920
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 7: no meter found for 1792 ppq
#   Skipping fix for measure 23: no meter found for 1792 ppq
#   Skipping fix for measure 27: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 34
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 36
# Found 5 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0920_rev.mei
# Getting DC0908
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 37
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0908_rev.mei
# Getting DC0713
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 14 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 1
#   Skipping fix for measure 3: no meter found for 1792 ppq
#   Skipping fix for measure 7: no meter found for 1792 ppq
# Inserted scoreDef meter.count=3 meter.unit=1 before measure 10
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 29
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 30
# Found 6 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0713_rev.mei
# Getting DC0707
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 22
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 24
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 32
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 33
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0707_rev.mei
# Getting DC0511
# Found 41 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 25: no meter found for 1792 ppq
#   Skipping fix for measure 41: no meter found for 5120 ppq
# Found 2 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC0511_rev.mei
# Getting DC0505
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 6: no meter found for 1792 ppq
#   Skipping fix for measure 12: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 25
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 26
# Found 4 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0505_rev.mei
# Getting DC1021
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 25
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC1021_rev.mei
# Getting DC0303
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 8
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 10
#   Skipping fix for measure 20: no meter found for 1792 ppq
#   Skipping fix for measure 28: no meter found for 5120 ppq
# Found 4 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0303_rev.mei
# Getting DC1009
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 32: no meter found for 5120 ppq
# Found 1 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC1009_rev.mei
# Getting DC0317
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 24
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 26
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 35
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0317_rev.mei
# Getting DC0101
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 28
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 30
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 36
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0101_rev.mei
# Getting DC0115
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 31
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0115_rev.mei
# Getting DC0103
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 1 choice elements to simplify.
# Replaced 1 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 8
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 9
#   Skipping fix for measure 27: no meter found for 5120 ppq
# Found 3 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0103_rev.mei
# Getting DC0117
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 45
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0117_rev.mei
# Getting DC0301
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 5 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 6: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 36
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 42
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 44
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 51
# Found 5 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0301_rev.mei
# Getting DC0315
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 26
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0315_rev.mei
# Getting DC1023
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 1 choice elements to simplify.
# Replaced 1 choice elements.
#   Skipping fix for measure 7: no meter found for 1792 ppq
#   Skipping fix for measure 13: no meter found for 1792 ppq
#   Skipping fix for measure 27: no meter found for 1792 ppq
#   Skipping fix for measure 31: no meter found for 1792 ppq
#   Skipping fix for measure 47: no meter found for 1792 ppq
#   Skipping fix for measure 62: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 64
# Found 7 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC1023_rev.mei
# Getting DC0513
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 12
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 14
#   Skipping fix for measure 31: no meter found for 0 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 32
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 33
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 43
# Found 6 meter mismatches.
# Inserted 5 corrective scoreDef elements.
# Saved updated DC0513_rev.mei
# Getting DC0507
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 5 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 18
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 38
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0507_rev.mei
# Getting DC0711
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 18
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 20
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 23
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0711_rev.mei
# Getting DC0705
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 11 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 31
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0705_rev.mei
# Getting DC0922
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 35
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 36
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0922_rev.mei
# Getting DC0923
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 48
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 49
# Found 2 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0923_rev.mei
# Getting DC0704
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 8
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 9
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 26
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 27
# Found 4 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0704_rev.mei
# Getting DC0710
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 5: no meter found for 1792 ppq
#   Skipping fix for measure 14: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 48
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 49
# Found 4 meter mismatches.
# Inserted 2 corrective scoreDef elements.
# Saved updated DC0710_rev.mei
# Getting DC0506
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 2 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 20: no meter found for 1792 ppq
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 43
# Found 2 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0506_rev.mei
# Getting DC0512
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 19: no meter found for 5120 ppq
# Found 1 meter mismatches.
# Inserted 0 corrective scoreDef elements.
# Saved updated DC0512_rev.mei
# Getting DC1022
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 31
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 33
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 39
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC1022_rev.mei
# Getting DC0314
# Found 0 variants to correct.
# Found scoreDef with meter.count=3 and meter.unit=1
# Found scoreDef with meter.count=3 and meter.unit=1
# Found 15 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 17
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 24
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 25
# Found 3 meter mismatches.
# Inserted 3 corrective scoreDef elements.
# Saved updated DC0314_rev.mei
# Getting DC0116
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
#   Skipping fix for measure 7: no meter found for 1792 ppq
#   Skipping fix for measure 15: no meter found for 1792 ppq
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 31
# Inserted scoreDef meter.count=4 meter.unit=2 before measure 33
# Inserted scoreDef meter.count=2 meter.unit=2 before measure 39
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 42
# Found 6 meter mismatches.
# Inserted 4 corrective scoreDef elements.
# Saved updated DC0116_rev.mei
# Getting DC0102
# Found 0 variants to correct.
# Found 0 3/1 measures check for mRests.
# Corrected 0 mRests
# Found 0 choice elements to simplify.
# Replaced 0 choice elements.
# Inserted scoreDef meter.count=4 meter.unit=1 before measure 41
# Found 1 meter mismatches.
# Inserted 1 corrective scoreDef elements.
# Saved updated DC0102_rev.mei
